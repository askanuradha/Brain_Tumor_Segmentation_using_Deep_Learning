# %% [markdown]
# ## Library Imports

# %%
import numpy as np
from tensorflow import keras
from keras import backend as K
from keras.models import load_model

# %% [markdown]
# ## Metrics

# %%
# dice loss as defined above for 4 classes
def dice_coef(y_true, y_pred, smooth=1.0):
    class_num = 4
    for i in range(class_num):
        y_true_f = K.flatten(y_true[:,:,:,i])
        y_pred_f = K.flatten(y_pred[:,:,:,i])
        intersection = K.sum(y_true_f * y_pred_f)
        loss = ((2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth))
        if i == 0:
            total_loss = loss
        else:
            total_loss = total_loss + loss
    total_loss = total_loss / class_num
    return total_loss

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# soft dice loss 
def soft_dice_loss(y_true, y_pred, epsilon=1e-6): 

    
    # skip the batch and class axis for calculating Dice score
    axes = tuple(range(1, len(y_pred.shape)-1)) 
    numerator = 2. * np.sum(y_pred * y_true, axes)
    denominator = np.sum(np.square(y_pred) + np.square(y_true), axes)
    
    return 1 - np.mean((numerator + epsilon) / (denominator + epsilon)) # average over classes and batch

#intersection over union
def iou(y_true, y_pred, smooth = 0.5):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# Computing Sensitivity      
def sensitivity(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

# Computing Specificity
def specificity(y_true, y_pred):
    true_negatives = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1-y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

def f1_score(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val
metrics = [f1_score, specificity, sensitivity, iou, soft_dice_loss, dice_coef, dice_coef_loss ]

# %% [markdown]
# ## Model Imports

# %%
# Define a custom_objects dictionary to specify the custom metric
custom_objects = {'f1_score': f1_score, 'specificity': specificity, 'sensitivity': sensitivity, 'iou': iou, 'soft_dice_loss': soft_dice_loss, 'dice_coef': dice_coef, 'dice_coef_loss': dice_coef_loss}

# Load the model using custom_objects
model = load_model('UNet++.h5', custom_objects=custom_objects)

# %% [markdown]
# ## Model Architecture

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 128, 128, 2)]        0         []
#
#  conv2d_6 (Conv2D)           (None, 128, 128, 16)         304       ['input_1[0][0]']
#
#  batch_normalization_5 (Bat  (None, 128, 128, 16)         64        ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 128, 128, 16)         0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 128, 128, 16)         2320      ['activation_2[0][0]']
#
#  batch_normalization_6 (Bat  (None, 128, 128, 16)         64        ['conv2d_7[0][0]']
#  chNormalization)
#
#  conv2d_8 (Conv2D)           (None, 128, 128, 16)         2320      ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 128, 128, 16)         2320      ['conv2d_8[0][0]']
#
#  batch_normalization_7 (Bat  (None, 128, 128, 16)         64        ['conv2d_9[0][0]']
#  chNormalization)
#
#  conv2d_10 (Conv2D)          (None, 128, 128, 16)         2320      ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  batch_normalization_8 (Bat  (None, 128, 128, 16)         64        ['conv2d_10[0][0]']
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 128, 128, 16)         2320      ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  batch_normalization_9 (Bat  (None, 128, 128, 16)         64        ['conv2d_11[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 128, 128, 16)         0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 16)           0         ['activation_3[0][0]']
#  D)
#
#  conv2d_18 (Conv2D)          (None, 64, 64, 32)           4640      ['max_pooling2d[0][0]']
#
#  batch_normalization_15 (Ba  (None, 64, 64, 32)           128       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  activation_6 (Activation)   (None, 64, 64, 32)           0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 64, 64, 32)           9248      ['activation_6[0][0]']
#
#  batch_normalization_16 (Ba  (None, 64, 64, 32)           128       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  conv2d_20 (Conv2D)          (None, 64, 64, 32)           9248      ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_21 (Conv2D)          (None, 64, 64, 32)           9248      ['conv2d_20[0][0]']
#
#  batch_normalization_17 (Ba  (None, 64, 64, 32)           128       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  conv2d_22 (Conv2D)          (None, 64, 64, 32)           9248      ['batch_normalization_17[0][0]
#                                                                     ']
#
#  batch_normalization_18 (Ba  (None, 64, 64, 32)           128       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  conv2d_23 (Conv2D)          (None, 64, 64, 32)           9248      ['batch_normalization_18[0][0]
#                                                                     ']
#
#  batch_normalization_19 (Ba  (None, 64, 64, 32)           128       ['conv2d_23[0][0]']
#  tchNormalization)
#
#  activation_7 (Activation)   (None, 64, 64, 32)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  max_pooling2d_1 (MaxPoolin  (None, 32, 32, 32)           0         ['activation_7[0][0]']
#  g2D)
#
#  conv2d_30 (Conv2D)          (None, 32, 32, 64)           18496     ['max_pooling2d_1[0][0]']
#
#  batch_normalization_25 (Ba  (None, 32, 32, 64)           256       ['conv2d_30[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 32, 32, 64)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 32, 32, 64)           36928     ['activation_10[0][0]']
#
#  batch_normalization_26 (Ba  (None, 32, 32, 64)           256       ['conv2d_31[0][0]']
#  tchNormalization)
#
#  conv2d_32 (Conv2D)          (None, 32, 32, 64)           36928     ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 32, 32, 64)           36928     ['conv2d_32[0][0]']
#
#  batch_normalization_27 (Ba  (None, 32, 32, 64)           256       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  conv2d_34 (Conv2D)          (None, 32, 32, 64)           36928     ['batch_normalization_27[0][0]
#                                                                     ']
#
#  batch_normalization_28 (Ba  (None, 32, 32, 64)           256       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  conv2d_35 (Conv2D)          (None, 32, 32, 64)           36928     ['batch_normalization_28[0][0]
#                                                                     ']
#
#  batch_normalization_29 (Ba  (None, 32, 32, 64)           256       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 32, 32, 64)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  max_pooling2d_2 (MaxPoolin  (None, 16, 16, 64)           0         ['activation_11[0][0]']
#  g2D)
#
#  conv2d_36 (Conv2D)          (None, 16, 16, 128)          73856     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_30 (Ba  (None, 16, 16, 128)          512       ['conv2d_36[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 16, 16, 128)          0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  conv2d_37 (Conv2D)          (None, 16, 16, 128)          147584    ['activation_12[0][0]']
#
#  batch_normalization_31 (Ba  (None, 16, 16, 128)          512       ['conv2d_37[0][0]']
#  tchNormalization)
#
#  conv2d_38 (Conv2D)          (None, 16, 16, 128)          147584    ['batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_39 (Conv2D)          (None, 16, 16, 128)          147584    ['conv2d_38[0][0]']
#
#  batch_normalization_32 (Ba  (None, 16, 16, 128)          512       ['conv2d_39[0][0]']
#  tchNormalization)
#
#  conv2d_40 (Conv2D)          (None, 16, 16, 128)          147584    ['batch_normalization_32[0][0]
#                                                                     ']
#
#  batch_normalization_33 (Ba  (None, 16, 16, 128)          512       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  conv2d_41 (Conv2D)          (None, 16, 16, 128)          147584    ['batch_normalization_33[0][0]
#                                                                     ']
#
#  batch_normalization_34 (Ba  (None, 16, 16, 128)          512       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 16, 16, 128)          0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_transpose (Conv2DTr  (None, 32, 32, 64)           32832     ['activation_13[0][0]']
#  anspose)
#
#  concatenate (Concatenate)   (None, 32, 32, 128)          0         ['conv2d_transpose[0][0]',
#                                                                      'activation_11[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 32, 32, 64)           73792     ['concatenate[0][0]']
#
#  batch_normalization_35 (Ba  (None, 32, 32, 64)           256       ['conv2d_42[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 32, 32, 64)           0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 32, 32, 64)           36928     ['activation_14[0][0]']
#
#  batch_normalization_36 (Ba  (None, 32, 32, 64)           256       ['conv2d_43[0][0]']
#  tchNormalization)
#
#  conv2d_44 (Conv2D)          (None, 32, 32, 64)           36928     ['batch_normalization_36[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 32, 32, 64)           36928     ['conv2d_44[0][0]']
#
#  batch_normalization_37 (Ba  (None, 32, 32, 64)           256       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  conv2d_46 (Conv2D)          (None, 32, 32, 64)           36928     ['batch_normalization_37[0][0]
#                                                                     ']
#
#  batch_normalization_38 (Ba  (None, 32, 32, 64)           256       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  conv2d_47 (Conv2D)          (None, 32, 32, 64)           36928     ['batch_normalization_38[0][0]
#                                                                     ']
#
#  batch_normalization_39 (Ba  (None, 32, 32, 64)           256       ['conv2d_47[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 32, 32, 64)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  conv2d_transpose_1 (Conv2D  (None, 64, 64, 32)           8224      ['activation_15[0][0]']
#  Transpose)
#
#  concatenate_1 (Concatenate  (None, 64, 64, 64)           0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'activation_7[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 64, 64, 32)           18464     ['concatenate_1[0][0]']
#
#  batch_normalization_40 (Ba  (None, 64, 64, 32)           128       ['conv2d_48[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 64, 64, 32)           0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 64, 64, 32)           9248      ['activation_16[0][0]']
#
#  batch_normalization_41 (Ba  (None, 64, 64, 32)           128       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  conv2d_50 (Conv2D)          (None, 64, 64, 32)           9248      ['batch_normalization_41[0][0]
#                                                                     ']
#
#  conv2d_51 (Conv2D)          (None, 64, 64, 32)           9248      ['conv2d_50[0][0]']
#
#  batch_normalization_42 (Ba  (None, 64, 64, 32)           128       ['conv2d_51[0][0]']
#  tchNormalization)
#
#  conv2d_52 (Conv2D)          (None, 64, 64, 32)           9248      ['batch_normalization_42[0][0]
#                                                                     ']
#
#  batch_normalization_43 (Ba  (None, 64, 64, 32)           128       ['conv2d_52[0][0]']
#  tchNormalization)
#
#  conv2d_53 (Conv2D)          (None, 64, 64, 32)           9248      ['batch_normalization_43[0][0]
#                                                                     ']
#
#  batch_normalization_44 (Ba  (None, 64, 64, 32)           128       ['conv2d_53[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 64, 64, 32)           0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_transpose_2 (Conv2D  (None, 128, 128, 16)         2064      ['activation_17[0][0]']
#  Transpose)
#
#  concatenate_2 (Concatenate  (None, 128, 128, 32)         0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'activation_3[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 128, 128, 16)         4624      ['concatenate_2[0][0]']
#
#  batch_normalization_45 (Ba  (None, 128, 128, 16)         64        ['conv2d_54[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 128, 128, 16)         0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_55 (Conv2D)          (None, 128, 128, 16)         2320      ['activation_18[0][0]']
#
#  batch_normalization_46 (Ba  (None, 128, 128, 16)         64        ['conv2d_55[0][0]']
#  tchNormalization)
#
#  conv2d_56 (Conv2D)          (None, 128, 128, 16)         2320      ['batch_normalization_46[0][0]
#                                                                     ']
#
#  conv2d_57 (Conv2D)          (None, 128, 128, 16)         2320      ['conv2d_56[0][0]']
#
#  batch_normalization_47 (Ba  (None, 128, 128, 16)         64        ['conv2d_57[0][0]']
#  tchNormalization)
#
#  conv2d_58 (Conv2D)          (None, 128, 128, 16)         2320      ['batch_normalization_47[0][0]
#                                                                     ']
#
#  batch_normalization_48 (Ba  (None, 128, 128, 16)         64        ['conv2d_58[0][0]']
#  tchNormalization)
#
#  conv2d_59 (Conv2D)          (None, 128, 128, 16)         2320      ['batch_normalization_48[0][0]
#                                                                     ']
#
#  batch_normalization_49 (Ba  (None, 128, 128, 16)         64        ['conv2d_59[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 128, 128, 16)         0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  conv2d_60 (Conv2D)          (None, 128, 128, 4)          68        ['activation_19[0][0]']
#
# ==================================================================================================
# Total params: 1467284 (5.60 MB)
# Trainable params: 1463764 (5.58 MB)
# Non-trainable params: 3520 (13.75 KB)
# __________________________________________________________________________________________________
